# %%
import pandas as pd
import numpy as np

# %%
#specify paths to original and alasysis data
Analysis_DIR = "../AnalysisData/"
Original_DIR = "../OriginalData/"

# %%
#read original data
wm = pd.read_csv(f"{Original_DIR}13_warminsko-mazurskie.csv")
display(wm)
# Out:
#      Unnamed: 0  Dni od zakupu       Marka  Wiek kupującego Płeć kupującego  \
# 0             0              5       Dyson             45.0               K
# 1             1              9       Dyson              NaN               K
# 2             2             11        Beko             44.0               K
# 3             3             10  Electrolux             40.0             bd.
# 4             4              5  Electrolux             62.0               K
# ..          ...            ...         ...              ...             ...
# 525         525              4       Dyson             36.0             bd.
# 526         526              6        Beko             18.0               M
# 527         527              8  Electrolux             43.0               K
# 528         528              5  Electrolux             30.0               K
# 529         529              5        Beko             47.0               K
#
#      Ocena
# 0      2.0
# 1      1.0
# 2      2.0
# ...

# %%
#prepare an analysis file
#drop unnecessary column 
wm = wm.drop(columns=['Unnamed: 0'])
#replacing 'NaN' with np.NaN
wm = wm.replace('NaN', np.NaN)

# %%
wm.head()
# Out:
#    Dni od zakupu       Marka  Wiek kupującego Płeć kupującego  Ocena
# 0              5       Dyson             45.0               K    2.0
# 1              9       Dyson              NaN               K    1.0
# 2             11        Beko             44.0               K    2.0
# 3             10  Electrolux             40.0             bd.    2.0
# 4              5  Electrolux             62.0               K    2.5

# %%
#create new analysis data files
wm.to_csv(f"{Analysis_DIR}wm_wide.csv", index=False)
